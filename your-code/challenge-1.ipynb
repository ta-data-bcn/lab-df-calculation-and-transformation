# %% [markdown]
# # Challenge 1
#
# In this challenge you will be working on **Pokemon**. You will answer a series of questions in order to practice dataframe calculation, aggregation, and transformation.
#
# ![Pokemon](../images/pokemon.jpg)
#
# Follow the instructions below and enter your code.
#
# #### Import all required libraries.

# %%
# import libraries
import pandas as pd
import numpy as np

# %% [markdown]
# #### Import data set.
#
# Import `pokemon_stats` table from database `Pokemon` from Ironhack's databases. Read the data into a dataframe called `pokemon`.
#
# *Data set attributed to [Alberto Barradas](https://www.kaggle.com/abcsds/pokemon/)*

# %%
# import data set from Ironhack's database
pokemon = pd.read_csv("../Datasets as CSV/Pokemon.csv")

# %%
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %% [markdown]
# #### Print first 10 rows of `pokemon`.

# %%
# your code here
pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %% [markdown]
# When you look at a data set, you often wonder what each column means. Some open-source data sets provide descriptions of the data set. In many cases, data descriptions are extremely useful for data analysts to perform work efficiently and successfully.
#
# For the `Pokemon.csv` data set, fortunately, the owner provided descriptions which you can see [here](https://www.kaggle.com/abcsds/pokemon/home). For your convenience, we are including the descriptions below. Read the descriptions and understand what each column means. This knowledge is helpful in your work with the data.
#
# | Column | Description |
# | --- | --- |
# | # | ID for each pokemon |
# | Name | Name of each pokemon |
# | Type 1 | Each pokemon has a type, this determines weakness/resistance to attacks |
# | Type 2 | Some pokemon are dual type and have 2 |
# | Total | A general guide to how strong a pokemon is |
# | HP | Hit points, or health, defines how much damage a pokemon can withstand before fainting |
# | Attack | The base modifier for normal attacks (eg. Scratch, Punch) |
# | Defense | The base damage resistance against normal attacks |
# | SP Atk | Special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) |
# | SP Def | The base damage resistance against special attacks |
# | Speed | Determines which pokemon attacks first each round |
# | Generation | Number of generation |
# | Legendary | True if Legendary Pokemon False if not |

# %% [markdown]
# #### Obtain the distinct values across `Type 1` and `Type 2`.
#
# Extract all the values in `Type 1` and `Type 2`. Then create an array containing the distinct values across both fields.

# %%
# your code here
array_1 = pokemon[["Type 1","Type 2"]] #creating the subset variable 
array_1 = np.array(array_1) #creating an array from the subset 

array_1
# Out:
# array([['Grass', 'Poison'],
#        ['Grass', 'Poison'],
#        ['Grass', 'Poison'],
#        ...,
#        ['Psychic', 'Ghost'],
#        ['Psychic', 'Dark'],
#        ['Fire', 'Water']], dtype=object)

# %% [markdown]
# #### Cleanup `Name` that contain "Mega".
#
# If you have checked out the pokemon names carefully enough, you should have found there are junk texts in the pokemon names which contain "Mega". We want to clean up the pokemon names. For instance, "VenusaurMega Venusaur" should be "Mega Venusaur", and "CharizardMega Charizard X" should be "Mega Charizard X".

# %%
# your code here
pokemon["Name"] = pokemon["Name"].str.replace(".*('Mega')", "Mega")
#".* means that everything that comes before Mega substitute it by Mega, you have to include Mega because it will include it"
#.* = Anything
#() = To specify a pattern that you want to find in a string
#?= to preserve this pattern and only take into consideration everything before
# This means that you want to replace anything that comes before the pattern (Mega) with nothing        

pokemon.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False
# 5       80       65     80           1      False
# 6      109       85    100           1      False
# 7      130       85    100           1      False
# 8      159      115    100           1      False
# 9       50       64     43           1      False

# %% [markdown]
# #### Create a new column called `A/D Ratio` whose value equals to `Attack` devided by `Defense`.
#
# For instance, if a pokemon has the Attack score 49 and Defense score 49, the corresponding `A/D Ratio` is 49/49=1.

# %%
pokemon.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
pokemon["A/D Ratio"] = pokemon["Attack"]/pokemon["Defense"]
pokemon.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'A/D Ratio'],
#       dtype='object')

# %%
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio
# 0       65       65     45           1      False   1.000000
# 1       80       80     60           1      False   0.984127
# 2      100      100     80           1      False   0.987952
# 3      122      120     80           1      False   0.813008
# 4       60       50     65           1      False   1.209302

# %% [markdown]
# #### Identify the pokemon with the highest `A/D Ratio`.

# %%
# By calculating the maximum value in the A/D Ratio series, we will get the highest ratio
max_ratio = pokemon["A/D Ratio"].max()
print(max_ratio)
#Here we are using loc to select rows that meet the condition inside column "Name"
pokemon.loc[pokemon["A/D Ratio"]== max_ratio, "Name"]
#Then we call the number 69 and it gives us the Pokemon Kadabra.
# Out:
# 9.0
# 429    DeoxysAttack Forme
# Name: Name, dtype: object

# %% [markdown]
# #### Identify the pokemon with the lowest A/D Ratio.

# %%
#Same as above
min_ratio = pokemon["A/D Ratio"].min()
pokemon.loc[pokemon["A/D Ratio"] == min_ratio, "Name"]
# Out:
# 230    Shuckle
# Name: Name, dtype: object

# %% [markdown]
# #### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`.
#
# Rules:
#
# * If both `Type 1` and `Type 2` have valid values, the `Combo Type` value should contain both values in the form of `<Type 1> <Type 2>`. For example, if `Type 1` value is `Grass` and `Type 2` value is `Poison`, `Combo Type` will be `Grass-Poison`.
#
# * If `Type 1` has valid value but `Type 2` is not, `Combo Type` will be the same as `Type 1`. For example, if `Type 1` is `Fire` whereas `Type 2` is `NaN`, `Combo Type` will be `Fire`.

# %%
pokemon.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'A/D Ratio'],
#       dtype='object')

# %%
pokemon["Combo Type"]= pokemon["Type 1"]

# %%
pokemon.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'A/D Ratio',
#        'Combo Type'],
#       dtype='object')

# %%
pokemon = pokemon[['#', 'Name', 'Type 1', 'Type 2','Combo Type', 'Total', 'HP', 'Attack', 'Defense',
       'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'A/D Ratio']]

# %%
pokemon.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Combo Type', 'Total', 'HP', 'Attack',
#        'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary',
#        'A/D Ratio'],
#       dtype='object')

# %%
# Combo Type 
#If Type 1 != NaN and If Type 2 != NaN then Combo Type = Type 1 and Type 2 
#If Type 1 == Grass and Type 2 == Poison then Combo Type = Grass-Poison
#If Type 1 != NaN and Type 2 == NaN then Combo Type = Type1
#If Type 1 == NaN and Type 2 != NaN then Combo Type = Type2

pokemon['Type 2'] = pokemon['Type 2'].fillna("")

def combo_mixer(row):
    if row['Type 2'] == "":
        return row['Type 1']
    else:
        return row['Type 1'] + '-' + row['Type 2']
pokemon['Combo Type'] = pokemon.apply(combo_mixer, axis=1)
pokemon.head()
# Out:
#    #                   Name Type 1  Type 2    Combo Type  Total  HP  Attack  \
# 0  1              Bulbasaur  Grass  Poison  Grass-Poison    318  45      49
# 1  2                Ivysaur  Grass  Poison  Grass-Poison    405  60      62
# 2  3               Venusaur  Grass  Poison  Grass-Poison    525  80      82
# 3  3  VenusaurMega Venusaur  Grass  Poison  Grass-Poison    625  80     100
# 4  4             Charmander   Fire                  Fire    309  39      52
#
#    Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary  A/D Ratio
# 0       49       65       65     45           1      False   1.000000
# 1       63       80       80     60           1      False   0.984127
# 2       83      100      100     80           1      False   0.987952
# 3      123      122      120     80           1      False   0.813008
# 4       43       60       50     65           1      False   1.209302

# %% [markdown]
# #### Identify the pokemon whose `A/D Ratio` are among the top 5.

# %%
#We are sorting the values of the dataframe Pokemon by the column A/D Ratio and we are telling them to show us the first 5 y
top5_Ratio = pokemon.sort_values("A/D Ratio", ascending=False).head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/Cellar/jupyterlab/2.1.2/libexec/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('A/D Ratio', 'Name')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-66-38c49369aff6> in <module>
#       1 #We are sorting the values of the dataframe Pokemon by the column A/D Ratio and we are telling them to show us the first 5 y
#       2 top5_Ratio = pokemon.sort_values("A/D Ratio", ascending=False).head(5)
# ----> 3 top5_Ratio[top5_Ratio["A/D Ratio","Name"]]
#
# /usr/local/Cellar/jupyterlab/2.1.2/libexec/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# /usr/local/Cellar/jupyterlab/2.1.2/libexec/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('A/D Ratio', 'Name')

# %% [markdown]
# #### For the 5 pokemon printed above, aggregate `Combo Type` and use a list to store the unique values.
#
# Your end product is a list containing the distinct `Combo Type` values of the 5 pokemon with the highest `A/D Ratio`.

# %%
top5_C_R = top5_Ratio.drop(["Type 1", "Type 2","Total","HP","Attack","Defense","Sp. Atk","Sp. Def","Speed","Generation","Legendary"], axis = 1)

# %%
top5_C_R
# Out:
#        #                   Name  Combo Type  A/D Ratio
# 429  386     DeoxysAttack Forme     Psychic      9.000
# 347  318               Carvanha  Water-Dark      4.500
# 19    15  BeedrillMega Beedrill  Bug-Poison      3.750
# 453  408               Cranidos        Rock      3.125
# 348  319               Sharpedo  Water-Dark      3.000

# %% [markdown]
# #### For each of the `Combo Type` values obtained from the previous question, calculate the mean scores of all numeric fields across all pokemon.
#
# Your output should look like below:
#
# ![Aggregate](../images/aggregated-mean.png)

# %%
pokemon["Combo Type"].value_counts()
# Out:
# Normal             61
# Water              59
# Psychic            38
# Grass              33
# Fire               28
#                    ..
# Electric-Water      1
# Psychic-Dark        1
# Grass-Ground        1
# Water-Steel         1
# Electric-Dragon     1
# Name: Combo Type, Length: 154, dtype: int64

# %%
pokemon.groupby("Combo Type").mean()
# Out:
#                         #       Total         HP      Attack     Defense  \
# Combo Type
# Bug            361.352941  289.705882  53.058824   50.352941   55.411765
# Bug-Electric   595.500000  395.500000  60.000000   62.000000   55.000000
# Bug-Fighting   214.000000  550.000000  80.000000  155.000000   95.000000
# Bug-Fire       636.500000  455.000000  70.000000   72.500000   60.000000
# Bug-Flying     286.285714  419.500000  63.000000   70.142857   61.571429
# ...                   ...         ...        ...         ...         ...
# Water-Ice      103.000000  511.666667  90.000000   83.333333  113.333333
# Water-Poison   118.666667  426.666667  61.666667   68.333333   58.333333
# Water-Psychic  111.800000  481.000000  87.000000   73.000000  104.000000
# Water-Rock     430.000000  428.750000  70.750000   82.750000  112.750000
# Water-Steel    395.000000  530.000000  84.000000   86.000000   88.000000
#
#                   Sp. Atk     Sp. Def      Speed  Generation  Legendary  \
# Combo Type
# Bug             39.294118   43.647059  47.941176    3.470588        0.0
# Bug-Electric    77.000000   55.000000  86.500000    5.000000        0.0
# Bug-Fighting    40.000000  100.000000  80.000000    2.000000        0.0
# Bug-Fire        92.500000   80.000000  80.000000    5.000000        0.0
# Bug-Flying      72.857143   69.071429  82.857143    2.857143        0.0
# ...                   ...         ...        ...         ...        ...
# Water-Ice       80.000000   78.333333  66.666667    1.000000        0.0
# Water-Poison    61.666667   91.666667  85.000000    1.333333        0.0
# Water-Psychic   94.000000   79.000000  44.000000    1.200000        0.0
# Water-Rock      61.500000   65.000000  36.000000    3.750000        0.0
# Water-Steel    111.000000  101.000000  60.000000    4.000000        0.0
#
#                A/D Ratio
# Combo Type
# Bug             0.940179
# Bug-Electric    1.111667
# Bug-Fighting    1.637681
# Bug-Fire        1.234266
# Bug-Flying      1.146274
# ...                  ...
# Water-Ice       0.821759
# Water-Poison    1.162149
# Water-Psychic   0.783668
# Water-Rock      0.727170
# Water-Steel     0.977273
#
# [154 rows x 11 columns]
