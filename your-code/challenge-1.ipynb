# %% [markdown]
# # Challenge 1
#
# In this challenge you will be working on **Pokemon**. You will answer a series of questions in order to practice dataframe calculation, aggregation, and transformation.
#
# ![Pokemon](../images/pokemon.jpg)
#
# Follow the instructions below and enter your code.
#
# #### Import all required libraries.

# %%
# import libraries
import pandas as pd
import numpy as np
import re

# %% [markdown]
# #### Import data set.
#
# Import `pokemon_stats` table from the file `Pokemon.csv` from the `data` folder. Read the data into a dataframe called `pokemon`.
#
# *Data set attributed to [Alberto Barradas](https://www.kaggle.com/abcsds/pokemon/)*

# %%
# import data set from Ironhack's database directory
pokemon_stats = pd.read_csv(filepath_or_buffer=("../data/Pokemon.csv"))

# %% [markdown]
# #### Print first 10 rows of `pokemon`.

# %%
# your code here
# explore the data set
pokemon_stats.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
#Tyoes of variables
pokemon_stats.info
# Out:
# <bound method DataFrame.info of        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %% [markdown]
# When you look at a data set, you often wonder what each column means. Some open-source data sets provide descriptions of the data set. In many cases, data descriptions are extremely useful for data analysts to perform work efficiently and successfully.
#
# For the `Pokemon.csv` data set, fortunately, the owner provided descriptions which you can see [here](https://www.kaggle.com/abcsds/pokemon/home). For your convenience, we are including the descriptions below. Read the descriptions and understand what each column means. This knowledge is helpful in your work with the data.
#
# | Column | Description |
# | --- | --- |
# | # | ID for each pokemon |
# | Name | Name of each pokemon |
# | Type 1 | Each pokemon has a type, this determines weakness/resistance to attacks |
# | Type 2 | Some pokemon are dual type and have 2 |
# | Total | A general guide to how strong a pokemon is |
# | HP | Hit points, or health, defines how much damage a pokemon can withstand before fainting |
# | Attack | The base modifier for normal attacks (eg. Scratch, Punch) |
# | Defense | The base damage resistance against normal attacks |
# | SP Atk | Special attack, the base modifier for special attacks (e.g. fire blast, bubble beam) |
# | SP Def | The base damage resistance against special attacks |
# | Speed | Determines which pokemon attacks first each round |
# | Generation | Number of generation |
# | Legendary | True if Legendary Pokemon False if not |

# %% [markdown]
# #### Obtain the distinct values across `Type 1` and `Type 2`.
#
# Extract all the values in `Type 1` and `Type 2`. Then create an array containing the distinct values across both fields.

# %%
# your code here

#show the values and the count for type 1
pokemon_stats['Type 1'].value_counts()
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ghost        32
# Ground       32
# Dark         31
# Poison       28
# Fighting     27
# Steel        27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
#show the array of all the values for type 1
pokemon_stats["Type 1"].values
# Out:
# array(['Grass', 'Grass', 'Grass', 'Grass', 'Fire', 'Fire', 'Fire', 'Fire',
#        'Fire', 'Water', 'Water', 'Water', 'Water', 'Bug', 'Bug', 'Bug',
#        'Bug', 'Bug', 'Bug', 'Bug', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Poison', 'Poison',
#        'Electric', 'Electric', 'Ground', 'Ground', 'Poison', 'Poison',
#        'Poison', 'Poison', 'Poison', 'Poison', 'Fairy', 'Fairy', 'Fire',
#        'Fire', 'Normal', 'Normal', 'Poison', 'Poison', 'Grass', 'Grass',
#        'Grass', 'Bug', 'Bug', 'Bug', 'Bug', 'Ground', 'Ground', 'Normal',
#        'Normal', 'Water', 'Water', 'Fighting', 'Fighting', 'Fire', 'Fire',
#        'Water', 'Water', 'Water', 'Psychic', 'Psychic', 'Psychic',
#        'Psychic', 'Fighting', 'Fighting', 'Fighting', 'Grass', 'Grass',
#        'Grass', 'Water', 'Water', 'Rock', 'Rock', 'Rock', 'Fire', 'Fire',
#        'Water', 'Water', 'Water', 'Electric', 'Electric', 'Normal',
# ...

# %%
#create an array of the distinc values of both types.
#first filter values 
t1_values=[[pokemon_stats["Type 1"].unique()]]

# %%
t1_values
# Out:
# [[array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#          'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#          'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)]]

# %%
t2_values=[[pokemon_stats["Type 2"].unique()]]

# %%
t2_values
# Out:
# [[array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#          'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#          'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)]]

# %%
#Instead of using the arrays, create df columns (series) of each type
df1=pokemon_stats["Type 1"]
df2=pokemon_stats["Type 2"]

# %%
type(df2) #type is what I expect
# Out:
# pandas.core.series.Series

# %%
df3=df1.append(df2)
df3
#if you append it like this, keeping the index, it stacks the old indexes.
#That is why the last index is 799, in a series of 1600 elements
# Out:
# 0      Grass
# 1      Grass
# 2      Grass
# 3      Grass
# 4       Fire
#        ...
# 795    Fairy
# 796    Fairy
# 797    Ghost
# 798     Dark
# 799    Water
# Length: 1600, dtype: object

# %%
#using ignore_index=True, the last index coincides with the length

# %%
df3=df1.append(df2, ignore_index=True)

# %%
df3
# Out:
# 0       Grass
# 1       Grass
# 2       Grass
# 3       Grass
# 4        Fire
#         ...
# 1595    Fairy
# 1596    Fairy
# 1597    Ghost
# 1598     Dark
# 1599    Water
# Length: 1600, dtype: object

# %%
type(df3)
# Out:
# pandas.core.series.Series

# %%
#result:
df3
# Out:
# 0       Grass
# 1       Grass
# 2       Grass
# 3       Grass
# 4        Fire
#         ...
# 1595    Fairy
# 1596    Fairy
# 1597    Ghost
# 1598     Dark
# 1599    Water
# Length: 1600, dtype: object

# %%
df3.unique()
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying', nan], dtype=object)

# %% [markdown]
# #### Cleanup `Name` that contain "Mega".
#
# If you have checked out the pokemon names carefully enough, you should have found there are junk texts in the pokemon names which contain "Mega". We want to clean up the pokemon names. For instance, "VenusaurMega Venusaur" should be "Mega Venusaur", and "CharizardMega Charizard X" should be "Mega Charizard X".

# %%
pokemon_stats.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
Name_to_modify=pokemon_stats['Name'].values

# %%
Name_to_modify
#split con mega, te quedas con el ultimo
# Out:
# array(['Bulbasaur', 'Ivysaur', 'Venusaur', 'VenusaurMega Venusaur',
#        'Charmander', 'Charmeleon', 'Charizard',
#        'CharizardMega Charizard X', 'CharizardMega Charizard Y',
#        'Squirtle', 'Wartortle', 'Blastoise', 'BlastoiseMega Blastoise',
#        'Caterpie', 'Metapod', 'Butterfree', 'Weedle', 'Kakuna',
#        'Beedrill', 'BeedrillMega Beedrill', 'Pidgey', 'Pidgeotto',
#        'Pidgeot', 'PidgeotMega Pidgeot', 'Rattata', 'Raticate', 'Spearow',
#        'Fearow', 'Ekans', 'Arbok', 'Pikachu', 'Raichu', 'Sandshrew',
#        'Sandslash', 'Nidoran♀', 'Nidorina', 'Nidoqueen', 'Nidoran♂',
#        'Nidorino', 'Nidoking', 'Clefairy', 'Clefable', 'Vulpix',
#        'Ninetales', 'Jigglypuff', 'Wigglytuff', 'Zubat', 'Golbat',
#        'Oddish', 'Gloom', 'Vileplume', 'Paras', 'Parasect', 'Venonat',
#        'Venomoth', 'Diglett', 'Dugtrio', 'Meowth', 'Persian', 'Psyduck',
#        'Golduck', 'Mankey', 'Primeape', 'Growlithe', 'Arcanine',
# ...

# %%
#test with only one string:
a="VenusaurMega Venusaur"
a=a.replace("Mega","___Mega")
a=a.split("___")
#a.split()
a[-1]
# Out:
# 'Mega Venusaur'

# %%
type(Name_to_modify)
#here, Name_to_modify is a numpy array
# Out:
# numpy.ndarray

# %%
#turn it into a list
Name_to_modify=list(Name_to_modify)
#it contains lines like this:
#'VenusaurMega Venusaur',
Name_to_modify
# Out:
# ['Bulbasaur',
#  'Ivysaur',
#  'Venusaur',
#  'VenusaurMega Venusaur',
#  'Charmander',
#  'Charmeleon',
#  'Charizard',
#  'CharizardMega Charizard X',
#  'CharizardMega Charizard Y',
#  'Squirtle',
#  'Wartortle',
#  'Blastoise',
#  'BlastoiseMega Blastoise',
#  'Caterpie',
#  'Metapod',
#  'Butterfree',
#  'Weedle',
#  'Kakuna',
#  'Beedrill',
#  'BeedrillMega Beedrill',
#  'Pidgey',
#  'Pidgeotto',
#  'Pidgeot',
#  'PidgeotMega Pidgeot',
#  'Rattata',
#  'Raticate',
#  'Spearow',
#  'Fearow',
#  'Ekans',
#  'Arbok',
#  'Pikachu',
#  'Raichu',
#  'Sandshrew',
#  'Sandslash',
#  'Nidoran♀',
#  'Nidorina',
#  'Nidoqueen',
#  'Nidoran♂',
#  'Nidorino',
#  'Nidoking',
#  'Clefairy',
#  'Clefable',
#  'Vulpix',
#  'Ninetales',
#  'Jigglypuff',
#  'Wigglytuff',
#  'Zubat',
#  'Golbat',
#  'Oddish',
#  'Gloom',
#  'Vileplume',
#  'Paras',
#  'Parasect',
#  'Venonat',
#  'Venomoth',
#  'Diglett',
#  'Dugtrio',
#  'Meowth',
#  'Persian',
#  'Psyduck',
#  'Golduck',
#  'Mankey',
# ...

# %%
Names_fixed=[]
for i in Name_to_modify:
    i= i.replace("Mega", "___Mega")
    i=i.split("___")
    Names_fixed.append(i[-1])

Names_fixed

#There is a more elegant way to do it:
#re.sub(r"\S*Mega","Mega",poke)
# Out:
# ['Bulbasaur',
#  'Ivysaur',
#  'Venusaur',
#  'Mega Venusaur',
#  'Charmander',
#  'Charmeleon',
#  'Charizard',
#  'Mega Charizard X',
#  'Mega Charizard Y',
#  'Squirtle',
#  'Wartortle',
#  'Blastoise',
#  'Mega Blastoise',
#  'Caterpie',
#  'Metapod',
#  'Butterfree',
#  'Weedle',
#  'Kakuna',
#  'Beedrill',
#  'Mega Beedrill',
#  'Pidgey',
#  'Pidgeotto',
#  'Pidgeot',
#  'Mega Pidgeot',
#  'Rattata',
#  'Raticate',
#  'Spearow',
#  'Fearow',
#  'Ekans',
#  'Arbok',
#  'Pikachu',
#  'Raichu',
#  'Sandshrew',
#  'Sandslash',
#  'Nidoran♀',
#  'Nidorina',
#  'Nidoqueen',
#  'Nidoran♂',
#  'Nidorino',
#  'Nidoking',
#  'Clefairy',
#  'Clefable',
#  'Vulpix',
#  'Ninetales',
#  'Jigglypuff',
#  'Wigglytuff',
#  'Zubat',
#  'Golbat',
#  'Oddish',
#  'Gloom',
#  'Vileplume',
#  'Paras',
#  'Parasect',
#  'Venonat',
#  'Venomoth',
#  'Diglett',
#  'Dugtrio',
#  'Meowth',
#  'Persian',
#  'Psyduck',
#  'Golduck',
#  'Mankey',
#  'Primeape',
#  'Growlithe',
#  'Arcanine',
#  'Poliwag',
# ...

# %%
pokemon_stats["Name_fixed"]=Names_fixed
#pokemon_stats.head(10)
#remove the original name column
pokemon_stats=pokemon_stats.drop(columns=["Name"])

# %%
# your code here


# test transformed data
pokemon_stats.head(4)
# Out:
#    # Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Grass  Poison    318  45      49       49       65       65     45
# 1  2  Grass  Poison    405  60      62       63       80       80     60
# 2  3  Grass  Poison    525  80      82       83      100      100     80
# 3  3  Grass  Poison    625  80     100      123      122      120     80
#
#    Generation  Legendary     Name_fixed
# 0           1      False      Bulbasaur
# 1           1      False        Ivysaur
# 2           1      False       Venusaur
# 3           1      False  Mega Venusaur

# %% [markdown]
# #### Create a new column called `A/D Ratio` whose value equals to `Attack` devided by `Defense`.
#
# For instance, if a pokemon has the Attack score 49 and Defense score 49, the corresponding `A/D Ratio` is 49/49=1.

# %%
# your code here

# %%
#create arrays for each column
Attack=pokemon_stats["Attack"].values
Defense=pokemon_stats["Defense"].values

# %%
#Attack
#output: array([ 49,  62,  82, 100,  52,  64,  84, 130, 104,  48,  63,  83, 103,
#        30,  20,  45,  35,  25,  90, 150,  45,  60,  80,  80,  56,  81,
#        60,  90,  60,  85,  55,  90,  75, 100,  47,  62,  92,  57,  72,
#       102,  45,  70,  41,  76,  45,  70,  45,  80,  50,  65,  80,  70,
#        95,  55,  65,  55,  80,  45,  70,  52,  82,  80, 105,  70, 110,
#        50,  65,  95,  20,  35,  50,  50,  80, 100, 130,  75,  90, 105,

# %%
#Defense
#output:
#array([ 49,  63,  83, 123,  43,  58,  78, 111,  78,  65,  80, 100, 120,
#        35,  55,  50,  30,  50,  40,  40,  40,  55,  75,  80,  35,  60,
#        30,  65,  44,  69,  40,  55,  85, 110,  52,  67,  87,  40,  57,
#        77,  48,  73,  40,  75,  20,  45,  35,  70,  55,  70,  85,  55,
#        80,  50,  60,  25,  50,  35,  60,  48,  78,  35,  60,  45,  80,
#        40,  65,  95,  15,  30,  45,  65,  50,  70,  80,  35,  50,  65,

# %%
#divide the arrays and name them
A_D_ratio=Attack/Defense

# %%
A_D_ratio
# Out:
# array([1.        , 0.98412698, 0.98795181, 0.81300813, 1.20930233,
#        1.10344828, 1.07692308, 1.17117117, 1.33333333, 0.73846154,
#        0.7875    , 0.83      , 0.85833333, 0.85714286, 0.36363636,
#        0.9       , 1.16666667, 0.5       , 2.25      , 3.75      ,
#        1.125     , 1.09090909, 1.06666667, 1.        , 1.6       ,
#        1.35      , 2.        , 1.38461538, 1.36363636, 1.23188406,
#        1.375     , 1.63636364, 0.88235294, 0.90909091, 0.90384615,
#        0.92537313, 1.05747126, 1.425     , 1.26315789, 1.32467532,
#        0.9375    , 0.95890411, 1.025     , 1.01333333, 2.25      ,
#        1.55555556, 1.28571429, 1.14285714, 0.90909091, 0.92857143,
#        0.94117647, 1.27272727, 1.1875    , 1.1       , 1.08333333,
#        2.2       , 1.6       , 1.28571429, 1.16666667, 1.08333333,
#        1.05128205, 2.28571429, 1.75      , 1.55555556, 1.375     ,
#        1.25      , 1.        , 1.        , 1.33333333, 1.16666667,
# ...

# %%
#add the new array as a new column
pokemon_stats["A/D Ratio"]=A_D_ratio

# %%
pokemon_stats.head()
# Out:
#    # Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Grass  Poison    318  45      49       49       65       65     45
# 1  2  Grass  Poison    405  60      62       63       80       80     60
# 2  3  Grass  Poison    525  80      82       83      100      100     80
# 3  3  Grass  Poison    625  80     100      123      122      120     80
# 4  4   Fire     NaN    309  39      52       43       60       50     65
#
#    Generation  Legendary     Name_fixed  A/D Ratio
# 0           1      False      Bulbasaur   1.000000
# 1           1      False        Ivysaur   0.984127
# 2           1      False       Venusaur   0.987952
# 3           1      False  Mega Venusaur   0.813008
# 4           1      False     Charmander   1.209302

# %% [markdown]
# #### Identify the pokemon with the highest `A/D Ratio`.

# %%
# your code here
pokemon_stats.tail()
# Out:
#        #   Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 795  719     Rock  Fairy    600  50     100      150      100      150     50
# 796  719     Rock  Fairy    700  50     160      110      160      110    110
# 797  720  Psychic  Ghost    600  80     110       60      150      130     70
# 798  720  Psychic   Dark    680  80     160       60      170      130     80
# 799  721     Fire  Water    600  80     110      120      130       90     70
#
#      Generation  Legendary           Name_fixed  A/D Ratio
# 795           6       True              Diancie   0.666667
# 796           6       True         Mega Diancie   1.454545
# 797           6       True  HoopaHoopa Confined   1.833333
# 798           6       True   HoopaHoopa Unbound   2.666667
# 799           6       True            Volcanion   0.916667

# %%
#DataFrame.sort_values(by, axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last', ignore_index=False, key=None)

# %%
#if you put inplace=True, it returns the df with the new order!!
#pokemon_stats.sort_values(["A/D Ratio"],ascending=False,inplace=True)

# %%
pokemon_stats.sort_values(["A/D Ratio"],ascending=False).head(10)
# Out:
#        #    Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 429  386   Psychic     NaN    600  50     180       20      180       20
# 347  318     Water    Dark    305  45      90       20       65       20
# 19    15       Bug  Poison    495  65     150       40       15       80
# 453  408      Rock     NaN    350  67     125       40       30       30
# 348  319     Water    Dark    460  70     120       40       95       40
# 428  386   Psychic     NaN    600  50     150       50      150       50
# 750  681     Steel   Ghost    520  60     150       50      150       50
# 454  409      Rock     NaN    495  97     165       60       65       50
# 798  720   Psychic    Dark    680  80     160       60      170      130
# 186  172  Electric     NaN    205  20      40       15       35       35
#
#      Speed  Generation  Legendary            Name_fixed  A/D Ratio
# 429    150           3       True    DeoxysAttack Forme   9.000000
# ...

# %%
# "#386" called "DeoxysAttack Forme" has the highest A/D Ratio

# %% [markdown]
# #### Identify the pokemon with the lowest A/D Ratio.

# %%
# your code here
pokemon_stats.sort_values(["A/D Ratio"]).head(3)
# Out:
#        # Type 1   Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 230  213    Bug     Rock    505  20      10      230       10      230      5
# 139  129  Water      NaN    200  20      10       55       15       20     80
# 484  436  Steel  Psychic    300  57      24       86       24       86     23
#
#      Generation  Legendary Name_fixed  A/D Ratio
# 230           2      False    Shuckle   0.043478
# 139           1      False   Magikarp   0.181818
# 484           4      False    Bronzor   0.279070

# %%
#"#213" called "Bronzor" has the highest A/D Ratio

# %% [markdown]
# #### Create a new column called `Combo Type` whose value combines `Type 1` and `Type 2`.
#
# Rules:
#
# * If both `Type 1` and `Type 2` have valid values, the `Combo Type` value should contain both values in the form of `<Type 1> <Type 2>`. For example, if `Type 1` value is `Grass` and `Type 2` value is `Poison`, `Combo Type` will be `Grass-Poison`.
#
# * If `Type 1` has valid value but `Type 2` is not, `Combo Type` will be the same as `Type 1`. For example, if `Type 1` is `Fire` whereas `Type 2` is `NaN`, `Combo Type` will be `Fire`.

# %%
pokemon_stats["Combo Type"] = pokemon_stats["Type 1"] + "-" + pokemon_stats["Type 2"]

# %%
pokemon_stats["Combo Type"]
# Out:
# 0       Grass-Poison
# 1       Grass-Poison
# 2       Grass-Poison
# 3       Grass-Poison
# 4                NaN
#            ...
# 795       Rock-Fairy
# 796       Rock-Fairy
# 797    Psychic-Ghost
# 798     Psychic-Dark
# 799       Fire-Water
# Name: Combo Type, Length: 800, dtype: object

# %%
pokemon_stats.loc[pokemon_stats["Type 2"].isna(), ["Combo Type"]] = pokemon_stats[pokemon_stats["Type 2"].isna()]["Type 1"]
pokemon_stats.head(10)
# Out:
#    # Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# 0  1  Grass  Poison    318  45      49       49       65       65     45
# 1  2  Grass  Poison    405  60      62       63       80       80     60
# 2  3  Grass  Poison    525  80      82       83      100      100     80
# 3  3  Grass  Poison    625  80     100      123      122      120     80
# 4  4   Fire     NaN    309  39      52       43       60       50     65
# 5  5   Fire     NaN    405  58      64       58       80       65     80
# 6  6   Fire  Flying    534  78      84       78      109       85    100
# 7  6   Fire  Dragon    634  78     130      111      130       85    100
# 8  6   Fire  Flying    634  78     104       78      159      115    100
# 9  7  Water     NaN    314  44      48       65       50       64     43
#
#    Generation  Legendary        Name_fixed  A/D Ratio    Combo Type
# 0           1      False         Bulbasaur   1.000000  Grass-Poison
# ...

# %%
pokemon_stats.tail(10)
# Out:
#        #   Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 790  714   Flying  Dragon    245   40      30       35       45       40
# 791  715   Flying  Dragon    535   85      70       80       97       80
# 792  716    Fairy     NaN    680  126     131       95      131       98
# 793  717     Dark  Flying    680  126     131       95      131       98
# 794  718   Dragon  Ground    600  108     100      121       81       95
# 795  719     Rock   Fairy    600   50     100      150      100      150
# 796  719     Rock   Fairy    700   50     160      110      160      110
# 797  720  Psychic   Ghost    600   80     110       60      150      130
# 798  720  Psychic    Dark    680   80     160       60      170      130
# 799  721     Fire   Water    600   80     110      120      130       90
#
#      Speed  Generation  Legendary           Name_fixed  A/D Ratio  \
# 790     55           6      False               Noibat   0.857143
# ...

# %% [markdown]
# #### Identify the pokemon whose `A/D Ratio` are among the top 5.

# %%
# your code here

# %%
#show the rows with highest AD Ratio
pokemon_stats.sort_values(["A/D Ratio"],ascending=False).head(10)
# Out:
#        #    Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 429  386   Psychic     NaN    600  50     180       20      180       20
# 347  318     Water    Dark    305  45      90       20       65       20
# 19    15       Bug  Poison    495  65     150       40       15       80
# 453  408      Rock     NaN    350  67     125       40       30       30
# 348  319     Water    Dark    460  70     120       40       95       40
# 428  386   Psychic     NaN    600  50     150       50      150       50
# 750  681     Steel   Ghost    520  60     150       50      150       50
# 454  409      Rock     NaN    495  97     165       60       65       50
# 798  720   Psychic    Dark    680  80     160       60      170      130
# 186  172  Electric     NaN    205  20      40       15       35       35
#
#      Speed  Generation  Legendary            Name_fixed  A/D Ratio  \
# 429    150           3       True    DeoxysAttack Forme   9.000000
# ...

# %%
#there is not a clear top5 as there is a tie for position 5

# %% [markdown]
# #### For the 5 pokemon printed above, aggregate `Combo Type` and use a list to store the unique values.
#
# Your end product is a list containing the distinct `Combo Type` values of the 5 pokemon with the highest `A/D Ratio`.

# %%
#create a new df with the best 5 (keeping all instances in case of a tie)
pokemon_combo =pokemon_stats.nlargest(5, "A/D Ratio", keep='all')

# %%
pokemon_combo
# Out:
#        #   Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 429  386  Psychic     NaN    600  50     180       20      180       20
# 347  318    Water    Dark    305  45      90       20       65       20
# 19    15      Bug  Poison    495  65     150       40       15       80
# 453  408     Rock     NaN    350  67     125       40       30       30
# 348  319    Water    Dark    460  70     120       40       95       40
# 428  386  Psychic     NaN    600  50     150       50      150       50
# 750  681    Steel   Ghost    520  60     150       50      150       50
#
#      Speed  Generation  Legendary            Name_fixed  A/D Ratio  \
# 429    150           3       True    DeoxysAttack Forme      9.000
# 347     65           3      False              Carvanha      4.500
# 19     145           1      False         Mega Beedrill      3.750
# 453     58           4      False              Cranidos      3.125
# ...

# %%
#show the unique values of the combo tyoe column:
pokemon_combo["Combo Type"].unique()
# Out:
# array(['Psychic', 'Water-Dark', 'Bug-Poison', 'Rock', 'Steel-Ghost'],
#       dtype=object)

# %%
#here I will like to merge the last two cells in one line:
# pokemon_combo =pokemon_stats.nlargest(5, "A/D Ratio", keep='all') and
# pokemon_combo["Combo Type"].unique()
pokemon_combo_1 =pokemon_stats.nlargest(5, "A/D Ratio", keep='all')["Combo Type"].unique()
#the previous line ensures to keep all the recors in a tie:
pokemon_combo_1 =pokemon_stats.nlargest(5, "A/D Ratio",)["Combo Type"].unique()

# %%
#pokemon_combo and pokemon_combo_1 are the same, done in one line and in two
pokemon_combo_1
# Out:
# array(['Psychic', 'Water-Dark', 'Bug-Poison', 'Rock'], dtype=object)

# %%
# I have not used aggregate

# %% [markdown]
# #### For each of the `Combo Type` values obtained from the previous question, calculate the mean scores of all numeric fields across all pokemon.
#
# Your output should look like below:
#
# ![Aggregate](../images/aggregated-mean.png)

# %%
# your code here
#df.groupby(by="a", dropna=False).sum()
pokemon_combo.groupby(by="Combo Type").mean()
# Out:
#                  #  Total    HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  \
# Combo Type
# Bug-Poison    15.0  495.0  65.0   150.0     40.0     15.0     80.0  145.0
# Psychic      386.0  600.0  50.0   165.0     35.0    165.0     35.0  150.0
# Rock         408.0  350.0  67.0   125.0     40.0     30.0     30.0   58.0
# Steel-Ghost  681.0  520.0  60.0   150.0     50.0    150.0     50.0   60.0
# Water-Dark   318.5  382.5  57.5   105.0     30.0     80.0     30.0   80.0
#
#              Generation  Legendary  A/D Ratio
# Combo Type
# Bug-Poison          1.0      False      3.750
# Psychic             3.0       True      6.000
# Rock                4.0      False      3.125
# Steel-Ghost         6.0      False      3.000
# Water-Dark          3.0      False      3.750

# %%
#df.groupby(by="a", dropna=False).sum()
pokemon_stats.groupby(by="Combo Type").mean()
# Out:
#                         #       Total         HP      Attack     Defense  \
# Combo Type
# Bug            361.352941  289.705882  53.058824   50.352941   55.411765
# Bug-Electric   595.500000  395.500000  60.000000   62.000000   55.000000
# Bug-Fighting   214.000000  550.000000  80.000000  155.000000   95.000000
# Bug-Fire       636.500000  455.000000  70.000000   72.500000   60.000000
# Bug-Flying     286.285714  419.500000  63.000000   70.142857   61.571429
# ...                   ...         ...        ...         ...         ...
# Water-Ice      103.000000  511.666667  90.000000   83.333333  113.333333
# Water-Poison   118.666667  426.666667  61.666667   68.333333   58.333333
# Water-Psychic  111.800000  481.000000  87.000000   73.000000  104.000000
# Water-Rock     430.000000  428.750000  70.750000   82.750000  112.750000
# Water-Steel    395.000000  530.000000  84.000000   86.000000   88.000000
#
#                   Sp. Atk     Sp. Def      Speed  Generation  Legendary  \
# ...

# %%
#pokemon_combo_grouped = (pokemon_stats.groupby(by="Combo Type")
#         .apply(lambda x: (x['Combo Type']== 'Bug').mean()))

# %%
# your code here
#DataFrame.aggregate(func=None, axis=0, *args, **kwargs)
#pokemon_stats.aggregate(["Combo Type"])
pokemon_stats.sort_values(["A/D Ratio"],ascending=False).head(10)
pokemon_stats.agg('Combo Type').sort_values(["A/D Ratio"],ascending=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-150-4bf907d5efa1> in <module>
#       3 #pokemon_stats.aggregate(["Combo Type"])
#       4 pokemon_stats.sort_values(["A/D Ratio"],ascending=False).head(10)
# ----> 5 pokemon_stats.agg('Combo Type').sort_values(["A/D Ratio"],ascending=False)
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/series.py in sort_values(self, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    3229         inplace = validate_bool_kwarg(inplace, "inplace")
#    3230         # Validate the axis parameter
# -> 3231         self._get_axis_number(axis)
#    3232
#    3233         # GH 5856/5853
#
# ~/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in _get_axis_number(cls, axis)
#     366     def _get_axis_number(cls, axis: Axis) -> int:
#     367         try:
# ...
