# %% [markdown]
# # Challenge 3
#
# In this challenge we will work on the `Orders` data set. In your work you will apply the thinking process and workflow we showed you in Challenge 2.
#
# You are serving as a Business Intelligence Analyst at the headquarter of an international fashion goods chain store. Your boss today asked you to do two things for her:
#
# **First, identify two groups of customers from the data set.** The first group is **VIP Customers** whose **aggregated expenses** at your global chain stores are **above the 95th percentile** (aka. 0.95 quantile). The second group is **Preferred Customers** whose **aggregated expenses** are **between the 75th and 95th percentile**.
#
# **Second, identify which country has the most of your VIP customers, and which country has the most of your VIP+Preferred Customers combined.**

# %% [markdown]
# ## Q1: How to identify VIP & Preferred Customers?
#
# We start by importing all the required libraries:

# %%
# import required libraries
import numpy as np
import pandas as pd

# %%
import os
os.path
# Out:
# <module 'posixpath' from '/Users/yidichi/opt/anaconda3/lib/python3.7/posixpath.py'>

# %%
os.getcwd()
# Out:
# '/Users/yidichi/ironhack/week2/Wednesday /lab-df-calculation-and-transformation/your-code'

# %% [markdown]
# Next, import `Orders` from the file `Oders.csv` located in the `data` folder into a dataframe variable called `orders`. Print the head of `orders` to overview the data:

# %%
# your code here

orders = pd.read_csv('../data/Orders.csv', index_col=0)

orders
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 0          536365    85123A  2010     12    3     8
# 1          536365     71053  2010     12    3     8
# 2          536365    84406B  2010     12    3     8
# 3          536365    84029G  2010     12    3     8
# 4          536365    84029E  2010     12    3     8
# ...           ...       ...   ...    ...  ...   ...
# 541904     581587     22613  2011     12    5    12
# 541905     581587     22899  2011     12    5    12
# 541906     581587     23254  2011     12    5    12
# 541907     581587     23255  2011     12    5    12
# 541908     581587     22138  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                       white metal lantern         6  2010-12-01 08:26:00
# 2            cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# ...

# %% [markdown]
# ---
#
# "Identify VIP and Preferred Customers" is the non-technical goal of your boss. You need to translate that goal into technical languages that data analysts use:
#
# ## How to label customers whose aggregated `amount_spent` is in a given quantile range?

# %% [markdown]
# We break down the main problem into several sub problems:
#
# #### Sub Problem 1: How to aggregate the  `amount_spent` for unique customers?
#
# #### Sub Problem 2: How to select customers whose aggregated `amount_spent` is in a given quantile range?
#
# #### Sub Problem 3: How to label selected customers as "VIP" or "Preferred"?
#
# *Note: If you want to break down the main problem in a different way, please feel free to revise the sub problems above.*
#
# Now in the workspace below, tackle each of the sub problems using the iterative problem solving workflow. Insert cells as necessary to write your codes and explain your steps.

# %%
# your code here

customers = orders.groupby('CustomerID')
total_amount = customers.aggregate({'amount_spent': np.sum,})

total_amount
# Out:
#             amount_spent
# CustomerID
# 12346           77183.60
# 12347            4310.00
# 12348            1797.24
# 12349            1757.55
# 12350             334.40
# ...                  ...
# 18280             180.60
# 18281              80.82
# 18282             178.05
# 18283            2094.88
# 18287            1837.28
#
# [4339 rows x 1 columns]

# %%
orders["Quantiles"] = pd.qcut(orders["amount_spent"],
                                    q=[0, 0.25, 0.5, 0.75, 0.95, 1], 
                                    labels=["Very Low", "Low", "Medium", "Preferred", "VIP"])

# %%
orders
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 0          536365    85123A  2010     12    3     8
# 1          536365     71053  2010     12    3     8
# 2          536365    84406B  2010     12    3     8
# 3          536365    84029G  2010     12    3     8
# 4          536365    84029E  2010     12    3     8
# ...           ...       ...   ...    ...  ...   ...
# 541904     581587     22613  2011     12    5    12
# 541905     581587     22899  2011     12    5    12
# 541906     581587     23254  2011     12    5    12
# 541907     581587     23255  2011     12    5    12
# 541908     581587     22138  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 0        white hanging heart t-light holder         6  2010-12-01 08:26:00
# 1                       white metal lantern         6  2010-12-01 08:26:00
# 2            cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# ...

# %%
vip_customers = orders[orders["Quantiles"]== 'VIP']

vip_customers
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 26         536370     22728  2010     12    3     8
# 27         536370     22727  2010     12    3     8
# 34         536370     22326  2010     12    3     8
# 40         536370     22900  2010     12    3     8
# 46         536371     22086  2010     12    3     9
# ...           ...       ...   ...    ...  ...   ...
# 541827     581579     23313  2011     12    5    12
# 541835     581579     23581  2011     12    5    12
# 541868     581584     85038  2011     12    5    12
# 541892     581586     21217  2011     12    5    12
# 541893     581586     20685  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 26                alarm clock bakelike pink        24  2010-12-01 08:45:00
# 27                alarm clock bakelike red         24  2010-12-01 08:45:00
# 34      round snack boxes set of4 woodland         24  2010-12-01 08:45:00
# ...

# %%
preferred_customers = orders[orders["Quantiles"]== 'Preferred']

preferred_customers
# Out:
#         InvoiceNo StockCode  year  month  day  hour  \
# 1          536365     71053  2010     12    3     8
# 2          536365    84406B  2010     12    3     8
# 3          536365    84029G  2010     12    3     8
# 4          536365    84029E  2010     12    3     8
# 6          536365     21730  2010     12    3     8
# ...           ...       ...   ...    ...  ...   ...
# 541889     581585     22466  2011     12    5    12
# 541890     581586     22061  2011     12    5    12
# 541891     581586     23275  2011     12    5    12
# 541894     581587     22631  2011     12    5    12
# 541902     581587     22629  2011     12    5    12
#
#                                 Description  Quantity          InvoiceDate  \
# 1                       white metal lantern         6  2010-12-01 08:26:00
# 2            cream cupid hearts coat hanger         8  2010-12-01 08:26:00
# 3       knitted union flag hot water bottle         6  2010-12-01 08:26:00
# ...

# %% [markdown]
# Now we'll leave it to you to solve Q2 & Q3, which you can leverage from your solution for Q1:
#
# ## Q2: How to identify which country has the most VIP Customers?

# %%
orders.groupby("Country")["Quantiles"].value_counts()
# Out:
# Country      Quantiles
# Australia    VIP          571
#              Preferred    272
#              Medium       229
#              Low           59
#              Very Low      54
#                          ...
# Unspecified  Very Low      93
#              Low           61
#              Medium        54
#              Preferred     34
#              VIP            2
# Name: Quantiles, Length: 169, dtype: int64

# %%
pd.crosstab(orders['Country'],orders['Quantiles'])

# Netherlandsv has the most VIP Customers
# Out:
# Quantiles             Very Low    Low  Medium  Preferred    VIP
# Country
# Australia                   54     59     229        272    571
# Austria                      2     77     201         91     27
# Bahrain                      0      1       5          9      2
# Belgium                     16    400    1034        542     39
# Brazil                       0      0      17         12      3
# Canada                       7     33      78         30      3
# Channel Islands              1     80     368        268     31
# Cyprus                     103     80     237        170     24
# Czech Republic               0      1       4         19      1
# Denmark                      2     66      95        155     62
# EIRE                       158   1142    3276       1947    715
# European Community           0      4      33         23      0
# Finland                      6    112     290        215     62
# France                     380   1675    3551       2343    393
# ...

# %% [markdown]
# ## Q3: How to identify which country has the most VIP+Preferred Customers combined?

# %%
# your code here

pd.crosstab(orders['Country'],orders['Quantiles'])

# England has the most VIP+Preferred customers combined
# Out:
# Quantiles             Very Low    Low  Medium  Preferred    VIP
# Country
# Australia                   54     59     229        272    571
# Austria                      2     77     201         91     27
# Bahrain                      0      1       5          9      2
# Belgium                     16    400    1034        542     39
# Brazil                       0      0      17         12      3
# Canada                       7     33      78         30      3
# Channel Islands              1     80     368        268     31
# Cyprus                     103     80     237        170     24
# Czech Republic               0      1       4         19      1
# Denmark                      2     66      95        155     62
# EIRE                       158   1142    3276       1947    715
# European Community           0      4      33         23      0
# Finland                      6    112     290        215     62
# France                     380   1675    3551       2343    393
# ...
