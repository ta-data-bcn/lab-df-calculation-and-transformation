# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
#defining functions to read csv
def read_csv(path):
    sales = pd.read_csv(path)
    return sales

# %%
sales = read_csv("sales_01.04.2015.csv")
sales.head()
# Out:
#    Unnamed: 0        date  shop_id  item_id  item_price  item_cnt_day
# 0     2553791  01.04.2015       29     1469      1199.0           1.0
# 1     2553959  01.04.2015       28    21364       479.0           1.0
# 2     2553979  01.04.2015       28    21365       999.0           2.0
# 3     2554011  01.04.2015       28    22104       249.0           2.0
# 4     2554035  01.04.2015       28    22091       179.0           1.0

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1515 entries, 0 to 1514
# Data columns (total 6 columns):
# Unnamed: 0      1515 non-null int64
# date            1515 non-null object
# shop_id         1515 non-null int64
# item_id         1515 non-null int64
# item_price      1515 non-null float64
# item_cnt_day    1515 non-null float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 71.1+ KB

# %%
def clean (df, column):
    if df[column] == "Unnamed":
        df[column] = df[column].astype("datetime64[ns]")
    elif df[column] == "date":
        df[column] = df[column].astype("object")
    return df[column]

# %%
sales["date"]  = sales["date"].astype("datetime64[ns]") 
sales["Unnamed: 0"] = sales["Unnamed: 0"].astype("object")

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1515 entries, 0 to 1514
# Data columns (total 6 columns):
# Unnamed: 0      1515 non-null object
# date            1515 non-null datetime64[ns]
# shop_id         1515 non-null int64
# item_id         1515 non-null int64
# item_price      1515 non-null float64
# item_cnt_day    1515 non-null float64
# dtypes: datetime64[ns](1), float64(2), int64(2), object(1)
# memory usage: 71.1+ KB

# %%
sales.head()
# Out:
#   Unnamed: 0       date  shop_id  item_id  item_price  item_cnt_day
# 0    2553791 2015-01-04       29     1469      1199.0           1.0
# 1    2553959 2015-01-04       28    21364       479.0           1.0
# 2    2553979 2015-01-04       28    21365       999.0           2.0
# 3    2554011 2015-01-04       28    22104       249.0           2.0
# 4    2554035 2015-01-04       28    22091       179.0           1.0

# %%
def group_shop (df, column1, column2):
    shop = df.groupby[column1].sum()
    item = df.groupby[column2].sum()
    return shop, item

# %%
def export(df,con, method = 'multi' )
    sales.to_sql(df, con=engine)
# Out:
#   File "<ipython-input-38-559c1f46bcd4>", line 1
#     def export(df, )
#                     ^
# SyntaxError: invalid syntax

# %%
sales.groupby(['shop_id']).sum()
# Out:
#          item_id     item_price  item_cnt_day
# shop_id
# 2         322293   33023.500000          27.0
# 3         111915   22481.000000          11.0
# 4         166208    9787.000000          13.0
# 5         206956   11046.000000          15.0
# 6         422298   38784.000000          50.0
# 7         223015   17457.000000          21.0
# 10        103379    7569.000000          10.0
# 12        549113   70732.133333          72.0
# 14        140659   11152.000000          17.0
# 15        403342   41713.000000          31.0
# 16        234812   39842.000000          22.0
# 18        266191   11797.000000          32.0
# 19        166867   20336.000000          20.0
# 21        586249   74939.500000          60.0
# 22        298018   41555.000000          47.0
# 24        199366   18985.000000          23.0
# 25       1094300   93932.000000         104.0
# 26        427613   39675.000000          37.0
# 27        645446   52108.000000          60.0
# ...

# %%
sales.groupby(['item_id']).sum()
# Out:
#          shop_id  item_price  item_cnt_day
# item_id
# 30            28      169.00           1.0
# 31             6      363.00           1.0
# 32            31      149.00           1.0
# 42            54      299.00           1.0
# 59            57      249.00           1.0
# 74            25      499.00           1.0
# 109           54      249.00           1.0
# 259           54      249.00           1.0
# 464           12      299.00           1.0
# 482           74     6600.00           4.0
# 486          146     1500.00           7.0
# 492           55      600.00           1.0
# 493           55      250.00           1.0
# 494           12      380.00           1.0
# 686           12     1500.00           1.0
# 687           47      600.00           1.0
# 787           22      420.00           1.0
# 799           55       25.00           1.0
# 803           55      100.00           1.0
# 806           50      498.00           4.0
# 837           22     4600.00           1.0
# ...
